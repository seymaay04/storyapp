# %% [markdown]
# TRAFİK ARTINCA SİSTEMİ 5 PODA ÇIKARIR

# %%
.\scripts\scale.ps1

# %% [markdown]
# KODLAR DEĞİŞİNCE KESİNTİSİZ GÜNCELLEME BAŞLATIR

# %%
.\scripts\update.ps1

# %% [markdown]
# YENİ SÜRÜMDE HATA ÇIKARSA SİSTEMİ ESKİ HALİNE GERİ ALIR

# %%
.\scripts\rollback.ps1
